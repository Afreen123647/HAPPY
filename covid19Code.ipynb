# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import math
data=pandas.read_csv('covid19.csv')
data.head()
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
data.drop('Sno',axis=1,inplace=True)
data
# Out:
#          Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    30/01/20               Kerala                        1
# 1    31/01/20               Kerala                        1
# 2    01/02/20               Kerala                        2
# 3    02/02/20               Kerala                        3
# 4    03/02/20               Kerala                        3
# ..        ...                  ...                      ...
# 265  21/03/20    Jammu and Kashmir                        4
# 266  21/03/20               Ladakh                       13
# 267  21/03/20        Uttar Pradesh                       23
# 268  21/03/20          Uttarakhand                        3
# 269  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# 3                           0      0       0
# ...

# %%
dataG = data.groupby('Date',axis=0,sort=False)
df=dataG.sum()
df
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df["Total"]=df.sum(axis=1)
df.head()
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
#
#           Total
# Date
# 30/01/20      1
# 31/01/20      1
# 01/02/20      2
# 02/02/20      3
# 03/02/20      3

# %%
plt.plot(df)
plt.title("national covid 19 cases")
plt.xlabel("Dates")
plt.ylabel("No. of cases")
plt.show()

# %%
G1=df.plot.line(title="national covid-19 cases")

# %%
T=[]
T=df['Total']
B=[]
B=T[33:]
B
# Out:
# Date
# 03/03/20      9
# 04/03/20     31
# 05/03/20     33
# 06/03/20     34
# 07/03/20     37
# 08/03/20     42
# 09/03/20     49
# 10/03/20     61
# 11/03/20     63
# 12/03/20     77
# 13/03/20     85
# 14/03/20     96
# 15/03/20    125
# 16/03/20    129
# 17/03/20    154
# 18/03/20    168
# 19/03/20    197
# 20/03/20    250
# 21/03/20    310
# Name: Total, dtype: int64

# %%
z=0
R=[]
i=0
for n in range(1,19):
    b=n-1
    x=B[b]
    y=B[n]
    r=((y-x)/x) #rate of increase
    z=z+r
R1=z/18      #mean of rate of increase

# %%
PO=31
t=26
e1=math.exp(R1*t)
pt=PO*e1
pt
# Out:
# 40243.70117662873

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

data=pandas.read_csv('covid19.csv')

Y=data.iloc[61:,1].values
X=data.iloc[61:,0]
plt.plot(X,Y)
